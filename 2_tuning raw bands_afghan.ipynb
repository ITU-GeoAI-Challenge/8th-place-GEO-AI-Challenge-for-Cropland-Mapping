# %%
# Initialization for the machine learning model
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, f1_score
from sklearn import preprocessing
from sklearn.model_selection import StratifiedKFold
import optuna
import xgboost as xgb
import os
import pandas as pd
import numpy as np
from scipy.interpolate import interp1d
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from matplotlib import pyplot as plt

# %% [markdown]
# ## load data

# %%
country = 'afghan'
mode = 'Train'
feature = 'raw'

path = '/app/dev/GeoITU/data'

X = np.load(os.path.join(path, '{}_{}_{}.npy'.format(country, mode, feature)), allow_pickle=True)
y_labels= np.load(os.path.join(path, '{}_{}_labels.npy'.format(country, mode)), allow_pickle=True)

assert X.shape[0] == y_labels.shape[0]

X = X.reshape(X.shape[0], -1)
print(X.shape, y_labels.shape)
# Out:
# (500, 180) (500,)

# %% [markdown]
# ## rf

# %%
# # Setting up the stratified k-fold cross-validation
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

accuracies = []  # List to store accuracy of each fold
f_scores = []
fold_num = 0
num_trial = 50

# 5-fold Stratified Cross Validation loop
for train_index, test_index in skf.split(X, y_labels):
    fold_num += 1

    # Splitting the dataset for this fold
    X_train, X_test = [X[i] for i in train_index], [X[i] for i in test_index]
    y_train_labels, y_test_labels = [y_labels[i] for i in train_index], [
        y_labels[i] for i in test_index
    ]
    
    
    # optimize params for single fold
    if fold_num == 1:  


        def objective(trial):
            params = {
            'n_estimators' : trial.suggest_int('n_estimators', 100, 1000),
            'max_depth' : trial.suggest_int('max_depth', 3, 15),
            # 'max_features' : trial.suggest_categorical('max_features', ['auto', 'sqrt']), 
            'min_samples_split' : trial.suggest_int('min_samples_split', 5, 32),
            'bootstrap' : trial.suggest_categorical('bootstrap', [True, False]),
            'n_jobs' : trial.suggest_categorical('n_jobs', [-1]) #fixed. use all cpus
            }

            clf = RandomForestClassifier(**params)
            clf.fit(X_train, y_train_labels)

            # Making predictions on the test set
            y_pred = clf.predict(X_test)

            # Calculating and reporting the accuracy
            accuracy = accuracy_score(y_test_labels, y_pred)
            return accuracy


        # optimize study
        study = optuna.create_study(direction="maximize")
        study.optimize(objective, n_trials=num_trial) 
        print(study.best_params)
                        
    # Model training
    clf = RandomForestClassifier(**study.best_params)  # change classifier here
    clf.fit(X_train, y_train_labels)
    
    # clf = xgb.XGBClassifier()
    # clf.fit(X_train, le.transform(y_train_labels))

    # Making predictions on the test set
    y_pred = clf.predict(X_test)

    # Calculating and reporting the accuracy
    accuracy = accuracy_score(y_test_labels, y_pred)
    accuracies.append(accuracy)  # Storing the accuracy
    
    # Calculating and reporting the fscore
    f_score = f1_score(y_test_labels, y_pred, average='weighted')
    f_scores.append(f_score)  # Storing the accuracy
    print(f"Fold {fold_num} Accuracy: {accuracy}")
    print(f"Fold {fold_num} F_score: {f_score}")

# Reporting the final results
avg_accuracy = np.mean(accuracies)
avg_fscore = np.mean(f_scores)
print(f"Average Accuracy across all folds: {avg_accuracy:.4f}")
print(f"Average Fscore across all folds: {avg_fscore:.4f}")
# Out:
# [I 2023-10-27 23:40:13,291] A new study created in memory with name: no-name-7ece32f2-7c85-4cf7-b819-5a37e4c3d465
# [I 2023-10-27 23:40:14,863] Trial 0 finished with value: 0.81 and parameters: {'n_estimators': 552, 'max_depth': 12, 'min_samples_split': 5, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:15,517] Trial 1 finished with value: 0.78 and parameters: {'n_estimators': 289, 'max_depth': 11, 'min_samples_split': 32, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:17,280] Trial 2 finished with value: 0.81 and parameters: {'n_estimators': 820, 'max_depth': 8, 'min_samples_split': 11, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:19,857] Trial 3 finished with value: 0.79 and parameters: {'n_estimators': 937, 'max_depth': 6, 'min_samples_split': 7, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:22,533] Trial 4 finished with value: 0.79 and parameters: {'n_estimators': 976, 'max_depth': 5, 'min_samples_split': 13, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:25,258] Trial 5 finished with value: 0.79 and parameters: {'n_estimators': 900, 'max_depth': 15, 'min_samples_split': 11, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:27,393] Trial 6 finished with value: 0.81 and parameters: {'n_estimators': 760, 'max_depth': 12, 'min_samples_split': 18, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:28,901] Trial 7 finished with value: 0.8 and parameters: {'n_estimators': 542, 'max_depth': 6, 'min_samples_split': 32, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:29,771] Trial 8 finished with value: 0.8 and parameters: {'n_estimators': 306, 'max_depth': 6, 'min_samples_split': 29, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:32,547] Trial 9 finished with value: 0.81 and parameters: {'n_estimators': 983, 'max_depth': 5, 'min_samples_split': 26, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:33,779] Trial 10 finished with value: 0.81 and parameters: {'n_estimators': 578, 'max_depth': 15, 'min_samples_split': 5, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:35,150] Trial 11 finished with value: 0.81 and parameters: {'n_estimators': 626, 'max_depth': 9, 'min_samples_split': 11, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:36,116] Trial 12 finished with value: 0.81 and parameters: {'n_estimators': 435, 'max_depth': 10, 'min_samples_split': 17, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:38,031] Trial 13 finished with value: 0.81 and parameters: {'n_estimators': 770, 'max_depth': 8, 'min_samples_split': 8, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:38,425] Trial 14 finished with value: 0.8 and parameters: {'n_estimators': 157, 'max_depth': 12, 'min_samples_split': 22, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:40,133] Trial 15 finished with value: 0.81 and parameters: {'n_estimators': 765, 'max_depth': 13, 'min_samples_split': 14, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:41,448] Trial 16 finished with value: 0.81 and parameters: {'n_estimators': 450, 'max_depth': 8, 'min_samples_split': 5, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:42,944] Trial 17 finished with value: 0.81 and parameters: {'n_estimators': 681, 'max_depth': 13, 'min_samples_split': 8, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:43,997] Trial 18 finished with value: 0.81 and parameters: {'n_estimators': 484, 'max_depth': 14, 'min_samples_split': 15, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:45,011] Trial 19 finished with value: 0.79 and parameters: {'n_estimators': 380, 'max_depth': 3, 'min_samples_split': 22, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:46,459] Trial 20 finished with value: 0.81 and parameters: {'n_estimators': 662, 'max_depth': 13, 'min_samples_split': 7, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:47,798] Trial 21 finished with value: 0.81 and parameters: {'n_estimators': 532, 'max_depth': 14, 'min_samples_split': 15, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:49,229] Trial 22 finished with value: 0.8 and parameters: {'n_estimators': 660, 'max_depth': 13, 'min_samples_split': 9, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:50,330] Trial 23 finished with value: 0.81 and parameters: {'n_estimators': 499, 'max_depth': 11, 'min_samples_split': 6, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:51,632] Trial 24 finished with value: 0.8 and parameters: {'n_estimators': 591, 'max_depth': 14, 'min_samples_split': 21, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:53,155] Trial 25 finished with value: 0.81 and parameters: {'n_estimators': 695, 'max_depth': 14, 'min_samples_split': 10, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:54,611] Trial 26 finished with value: 0.8 and parameters: {'n_estimators': 512, 'max_depth': 11, 'min_samples_split': 5, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:55,414] Trial 27 finished with value: 0.8 and parameters: {'n_estimators': 361, 'max_depth': 11, 'min_samples_split': 16, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:56,015] Trial 28 finished with value: 0.79 and parameters: {'n_estimators': 203, 'max_depth': 12, 'min_samples_split': 10, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:58,549] Trial 29 finished with value: 0.8 and parameters: {'n_estimators': 852, 'max_depth': 9, 'min_samples_split': 13, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:40:59,827] Trial 30 finished with value: 0.81 and parameters: {'n_estimators': 447, 'max_depth': 10, 'min_samples_split': 5, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:01,383] Trial 31 finished with value: 0.8 and parameters: {'n_estimators': 713, 'max_depth': 14, 'min_samples_split': 7, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:02,640] Trial 32 finished with value: 0.81 and parameters: {'n_estimators': 585, 'max_depth': 15, 'min_samples_split': 13, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:03,828] Trial 33 finished with value: 0.8 and parameters: {'n_estimators': 407, 'max_depth': 10, 'min_samples_split': 6, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:04,744] Trial 34 finished with value: 0.79 and parameters: {'n_estimators': 318, 'max_depth': 10, 'min_samples_split': 9, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:06,431] Trial 35 finished with value: 0.79 and parameters: {'n_estimators': 591, 'max_depth': 15, 'min_samples_split': 12, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:08,606] Trial 36 finished with value: 0.8 and parameters: {'n_estimators': 708, 'max_depth': 15, 'min_samples_split': 10, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:10,931] Trial 37 finished with value: 0.79 and parameters: {'n_estimators': 831, 'max_depth': 14, 'min_samples_split': 12, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:12,240] Trial 38 finished with value: 0.8 and parameters: {'n_estimators': 468, 'max_depth': 12, 'min_samples_split': 9, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:13,391] Trial 39 finished with value: 0.81 and parameters: {'n_estimators': 530, 'max_depth': 13, 'min_samples_split': 20, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:14,154] Trial 40 finished with value: 0.8 and parameters: {'n_estimators': 255, 'max_depth': 15, 'min_samples_split': 7, 'bootstrap': True, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:15,479] Trial 41 finished with value: 0.8 and parameters: {'n_estimators': 617, 'max_depth': 11, 'min_samples_split': 5, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:16,685] Trial 42 finished with value: 0.81 and parameters: {'n_estimators': 559, 'max_depth': 13, 'min_samples_split': 25, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:18,182] Trial 43 finished with value: 0.81 and parameters: {'n_estimators': 624, 'max_depth': 12, 'min_samples_split': 19, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:19,388] Trial 44 finished with value: 0.81 and parameters: {'n_estimators': 543, 'max_depth': 9, 'min_samples_split': 24, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:20,639] Trial 45 finished with value: 0.81 and parameters: {'n_estimators': 566, 'max_depth': 13, 'min_samples_split': 28, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:22,020] Trial 46 finished with value: 0.81 and parameters: {'n_estimators': 626, 'max_depth': 12, 'min_samples_split': 19, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:23,181] Trial 47 finished with value: 0.79 and parameters: {'n_estimators': 534, 'max_depth': 7, 'min_samples_split': 25, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:24,527] Trial 48 finished with value: 0.79 and parameters: {'n_estimators': 635, 'max_depth': 9, 'min_samples_split': 27, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# [I 2023-10-27 23:41:26,146] Trial 49 finished with value: 0.8 and parameters: {'n_estimators': 726, 'max_depth': 14, 'min_samples_split': 15, 'bootstrap': False, 'n_jobs': -1}. Best is trial 0 with value: 0.81.
# {'n_estimators': 552, 'max_depth': 12, 'min_samples_split': 5, 'bootstrap': True, 'n_jobs': -1}
# Fold 1 Accuracy: 0.8
# Fold 1 F_score: 0.8000000000000002
# Fold 2 Accuracy: 0.87
# Fold 2 F_score: 0.8699869986998701
# Fold 3 Accuracy: 0.79
# Fold 3 F_score: 0.7899789978997899
# Fold 4 Accuracy: 0.88
# Fold 4 F_score: 0.879951980792317
# Fold 5 Accuracy: 0.78
# Fold 5 F_score: 0.7796474358974359
# Average Accuracy across all folds: 0.8240
# Average Fscore across all folds: 0.8239
